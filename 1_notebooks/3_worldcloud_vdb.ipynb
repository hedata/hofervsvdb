# %%
import pandas as pd
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
# %matplotlib inline
csvname='vdb_clean_done'
df = pd.read_csv(csvname+'.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  index              id_str           created_at  \
# 0          43     43  805546281846374401  2016-12-04 22:56:14
# 1          44     44  805495246486433793  2016-12-04 19:33:26
# 2          45     45  805361714472648704  2016-12-04 10:42:50
# 3          46     46  805305739719962625  2016-12-04 07:00:24
# 4          47     47  805064145896927233  2016-12-03 15:00:24
#
#                                                 text  \
# 0                #mehrdennje https://t.co/igaXUxRa8T
# 1         #mehrdennje #bpw16 https://t.co/6eK0FkrKpL
# 2  Hohes nationales und internationales Medienauf...
# 3  Heute zählt jede einzelne Stimme! Gehen Sie bi...
# 4  Morgen Sonntag: #VanderBellen wählen! #bpw16 h...
#
#                                             entities  favorite_count  \
# 0  {'symbols': [], 'urls': [], 'hashtags': [{'tex...             637
# 1  {'symbols': [], 'urls': [], 'hashtags': [{'tex...            2430
# 2  {'symbols': [], 'urls': [{'expanded_url': 'htt...             376
# 3  {'symbols': [], 'urls': [], 'hashtags': [{'tex...             876
# 4  {'symbols': [], 'urls': [], 'hashtags': [{'tex...             562
#
#    retweet_count  followers_count  friends_count retweeted retweetedstatus  \
# 0            188            36964            258     False           False
# 1            899            36964            258     False           False
# 2            117            36964            258     False           False
# 3            496            36964            258     False           False
# 4            290            36964            258     False           False
#
#                       hashtags             datetime        time
# 0                   mehrdennje  2016-12-04 22:56:14  2016-12-04
# 1             mehrdennje bpw16  2016-12-04 19:33:26  2016-12-04
# 2                 VanderBellen  2016-12-04 10:42:50  2016-12-04
# 3   VanderBellen bpw16 wahltag  2016-12-04 07:00:24  2016-12-04
# 4           VanderBellen bpw16  2016-12-03 15:00:24  2016-12-03

# %%
stop = set(stopwords.words('german'))

# %%
stop.add('aber')
stop.add('beim')
stop.add('schon')
stop.add('dass')

# %%
# join tweets to a single string
words = ' '.join(df['text'])

# remove URLs, RTs, and twitter handles
no_urls_no_tags = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and not word.startswith('#')
                                and word != 'RT'
                                and word.lower() not in stop
                            ])

# Generate a word cloud image
wordcloud = WordCloud(background_color="white",width=600,height=600).generate(no_urls_no_tags)

# Display the generated image:
# the matplotlib way:
fig = plt.figure(figsize = (15,15))
ax = fig.add_subplot(111)
ax.imshow(wordcloud)
ax.axis("off")
# Out:
# (-0.5, 599.5, 599.5, -0.5)

# %%
 df['hashtags'] = df['hashtags'].astype('str')

# %%
# join tweets to a single string
words = ' '.join(df['hashtags'])

# remove URLs, RTs, and twitter handles
no_urls_no_tags = " ".join([word for word in words.split()
                            if 'http' not in word
                                and not word.startswith('@')
                                and not word.startswith('#')
                                and word != 'RT'
                                and word != 'nan'
                                and word.lower() not in stop
                            ])

# Generate a word cloud image
wordcloud = WordCloud(background_color="white",width=600,height=600).generate(no_urls_no_tags)

# Display the generated image:
# the matplotlib way:
fig = plt.figure(figsize = (15,15))
ax = fig.add_subplot(111)
ax.imshow(wordcloud)
ax.axis("off")
# Out:
# (-0.5, 599.5, 599.5, -0.5)
